# %%
# used for initializing the shapelets via KMeans
# NOTE: if you are just looking for a working solution of the learning shapelets algorithm you are advised to just use the implementation that is already provided by tslearn.
! pip install --user tslearn matplotlib
# Out:
# Requirement already satisfied: tslearn in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (0.5.2)
# Requirement already satisfied: matplotlib in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (3.5.3)
# Requirement already satisfied: numpy in c:\users\dema2\appdata\roaming\python\python310\site-packages (from tslearn) (1.23.5)
# Requirement already satisfied: joblib in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from tslearn) (1.1.0)
# Requirement already satisfied: scipy in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from tslearn) (1.9.1)
# Requirement already satisfied: numba in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from tslearn) (0.56.4)
# Requirement already satisfied: scikit-learn in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from tslearn) (1.1.2)
# Requirement already satisfied: Cython in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from tslearn) (0.29.32)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.28.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.0.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: six>=1.5 in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from numba->tslearn) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from numba->tslearn) (58.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dema2\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->tslearn) (3.1.0)

# %% [markdown]
# ## Demo $\mathcal{L_R}$ loss

# %% [markdown]
# Demonstrates the use and effects of the regularized loss $\mathcal{L_R}$.

# %% [markdown]
# The data set used is the *UWaveGestureLibraryAll* dataset of the UCR archive:
# > Yanping Chen, Eamonn Keogh, Bing Hu, Nurjahan Begum, Anthony Bagnall, Abdullah Mueen and Gustavo Batista (2015). The UCR Time Series Classification Archive. URL www.cs.ucr.edu/~eamonn/time_series_data/.

# %% [markdown]
# ### NOTE I
# The demo was performed on a GPU. You need to set `to_cuda=False` at the respective places in case you want to run on CPU.

# %% [markdown]
# ### NOTE II
# To demonstrate the implementation, the shapelets to be learned are initialized via K-Means as was done in the original paper. To do so, we use the K-Means implementation of the library TSLearn. If you are just looking for a working implementation of LearningShapelets, you are advised to just use the TSLearn implementation. This repo just intends to provide an exemplary implementation using PyTorch.

# %%
import os
## TODO change to 0
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

import sys
sys.path.insert(0, os.path.abspath('../'))
sys.path.insert(0, os.getcwd())

# %%
import random
import numpy
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from tslearn.clustering import TimeSeriesKMeans
import torch
from torch import nn, optim

# %%
from src.learning_shapelets import LearningShapelets

# %% [markdown]
# ### Load and Normalze Data

# %% [markdown]
# Helper functions to normalize the data:

# %%
def normalize_standard(X, scaler=None):
    shape = X.shape
    data_flat = X.flatten()
    if scaler is None:
        scaler = StandardScaler()
        data_transformed = scaler.fit_transform(data_flat.reshape(numpy.product(shape), 1)).reshape(shape)
    else:
        data_transformed = scaler.transform(data_flat.reshape(numpy.product(shape), 1)).reshape(shape)
    return data_transformed, scaler

def normalize_data(X, scaler=None):
    if scaler is None:
        X, scaler = normalize_standard(X)
    else:
        X, scaler = normalize_standard(X, scaler)
    
    return X, scaler

# %% [markdown]
# Load and normalize training data:

# %%
dataset = "UWaveGestureLibraryAll"
# Load training data
X_train = numpy.load(open(os.path.join('data', f'{dataset}_train.npy'), 'rb'))
X_train_size = X_train.shape[0]
print(f"Shape X_train: {X_train.shape}")

# load trainng data labels
y_train = numpy.load(open(os.path.join('data', f'{dataset}_train_labels.npy'), 'rb'))
print(f"Shape y_train: {y_train.shape}")

print(y_train.ndim)

# normalize training data
X_train, scaler = normalize_data(X_train)

# print("This is X_train", X_train)
# print("This is y_train", y_train)

print(X_train[3,0])
# Out:
# Shape X_train: (896, 1, 945)
# Shape y_train: (896,)
# 1
# [ 0.16497475  0.16497475  0.16497475  0.16497475  0.16497475  0.16497475
#   0.16497475  0.16497475  0.16497475  0.16497475  0.16497475  0.16497475
#   0.16497475  0.16497475  0.16497475  0.16497475  0.16497475  0.16497475
#   0.16497475  0.16497475  0.16497475  0.16497475  0.16497475  0.16497475
#   0.16497475  0.16497475  0.16497475  0.16497475  0.16497475  0.16497475
#   0.16497475  0.16497475  0.30576233  0.16664296  0.30919067  0.43174474
#   0.48478407  0.09268098  0.47002184  0.40637384  0.26372825  0.09981836
#  -0.08481938 -0.38184205 -0.14190638 -0.19706846 -0.22677072 -0.25647299
#  -0.27455967 -0.2575868  -0.23040783 -0.20672714 -0.19399773 -0.19282499
#  -0.19771377 -0.20858515 -0.23828741 -0.26558525 -0.28799331 -0.28799331
#  -0.28799331 -0.29422165 -0.32180219 -0.35103496 -0.38073722 -0.41043949
#  -0.44014176 -0.46334297 -0.47819411 -0.47833096 -0.47833096 -0.47833096
#  -0.47833096 -0.47833096 -0.47833096 -0.47833096 -0.47833096 -0.47833096
#  -0.47833096 -0.47833096 -0.47833096 -0.47833096 -0.47833096 -0.48495988
#  -0.49894094 -0.52864321 -0.55435574 -0.57349928 -0.57349928 -0.57349928
#  -0.58198622 -0.61168848 -0.64139075 -0.67109302 -0.70079528 -0.73049755
#  -0.76019982 -0.78990209 -0.81960435 -0.84290246 -0.85900526 -0.85900526
#  -0.85900526 -0.85900526 -0.85900526 -0.85900526 -0.84883712 -0.82125658
#  -0.79172014 -0.77208812 -0.76383693 -0.76383693 -0.77245972 -0.78929573
#  -0.818998   -0.84287349 -0.85900526 -0.85900526 -0.85900526 -0.85900526
#  -0.85900526 -0.85900526 -0.85900526 -0.85900526 -0.85900526 -0.85900526
#  -0.85900526 -0.85900526 -0.86745223 -0.8838587  -0.91356097 -0.94326323
#  -0.9729655  -1.00266775 -1.03237007 -1.07480173 -1.13420627 -1.19361081
#  -1.24054064 -1.27604974 -1.30575196 -1.32458282 -1.33484886 -1.33484886
#  -1.32692936 -1.31060182 -1.2808995  -1.25119728 -1.22149496 -1.19179275
#  -1.16209043 -1.14649607 -1.14451122 -1.14451122 -1.14451122 -1.14451122
#  -1.14451122 -1.15525571 -1.17421354 -1.20391576 -1.2124996  -1.19239907
#  -1.13299453 -1.07557384 -1.03176365 -1.00206143 -0.97235915 -0.94265688
#  -0.91295462 -0.88325235 -0.84017537 -0.78868938 -0.72928485 -0.68014634
#  -0.6395717  -0.60986943 -0.58016716 -0.55046489 -0.52076263 -0.49106036
#  -0.52924956 -0.61835636 -0.70746316 -0.78076085 -0.84506315 -0.90446768
#  -0.92398284 -0.91962249 -0.88992023 -0.85078304 -0.80202513 -0.74262059
#  -0.68321607 -0.62381153 -0.564407   -0.50500247 -0.44559793 -0.3861934
#  -0.32678787 -0.2835161  -0.24798605 -0.21828378 -0.20144777 -0.19282499
#  -0.19282499 -0.20107617 -0.2207082  -0.25024464 -0.27782518 -0.28799331
#  -0.28799331 -0.28799331 -0.30676525 -0.33345574 -0.36315801 -0.39286128
#  -0.42256354 -0.45226581 -0.4577989  -0.44499158 -0.41458507 -0.3721534
#  -0.30132907 -0.21222227 -0.12311547 -0.17852027  0.10601674  0.22482581
#   0.32449232  0.41758786  0.50669466  0.54863785  0.56852461  0.56784033
#   0.54662401  0.50305755  0.44365302  0.38424848  0.32484395  0.26543941
#   0.20603488  0.19060637  0.18784931  0.18784931  0.24533789  0.32060048
#   0.40970728  0.49881508  0.58792188  0.6789836   0.78506426  0.91949664
#   1.06753848  1.21392906  1.33896644  1.45777551  1.57658459  1.69539367
#   1.81420275  1.93301183  2.05182191  2.17063099  2.28826624  2.39434699
#   2.48947633  2.57480019  2.64481234  2.66223476  2.66223476  2.66223476
#   2.58585734  2.49675058  2.40764272  2.31853596  2.2294291   2.14149507
#   2.06936119  2.00514671  1.94574227  1.88633673  1.82693219  1.77110584
#   1.72443064  1.74146245  1.77116477  1.80086699  1.77871267  1.75116109
#   1.72145887  1.69175655  1.66205433  1.6346106   1.61975944  1.61537912
#   1.61318947  1.60470257  1.57900908  1.54930676  1.51960454  1.48990222
#   1.4602      1.42991137  1.37474927  1.31714379  1.25773925  1.19833471
#   1.13893017  1.0855093   1.05156353  1.04436722  1.03568553  1.01022665
#   0.90131106  0.78250199  0.66369293  0.36600097  0.36600097  0.36600097
#   0.36600097  0.36600097  0.36600097  0.36600097  0.36600097  0.36600097
#   0.36600097  0.36600097  0.36600097  0.36600097  0.36600097  0.36600097
#   0.36600097  0.36600097  0.36600097  0.36600097  0.36600097  0.36600097
#   0.36600097  0.36600097  0.36600097  0.36600097  0.36600097  0.36600097
#   0.36600097  0.36600097  0.36600097  0.36600097  0.36600097  0.37411131
#   0.42299709  0.4777406   0.52480631  0.54517555  0.54874174  0.55797888
#   0.58242176  0.63720323  0.68832362  0.7314835   0.7314835   0.7314835
#   0.7314835   0.7314835   0.7314835   0.7314835   0.7314835   0.7314835
#   0.74304815  0.77563933  0.8304198   0.86868092  0.8839626   0.82692853
#   0.77451253  0.7314835   0.7314835   0.7314835   0.7314835   0.7314835
#   0.7314835   0.7314835   0.7314835   0.7314835   0.7314835   0.7314835
#   0.7314835   0.7314835   0.7314835   0.7314835   0.72883633  0.71402416
#   0.65699009  0.59995602  0.54292196  0.48588789  0.42885483  0.38702751
#   0.36665728  0.36600097  0.36600097  0.36600097  0.36600097  0.36600097
#   0.36600097  0.36600097  0.36600097  0.36600097  0.36600097  0.36600097
#   0.38355422  0.42836635  0.48472414  0.52553754  0.54874174  0.54874174
#   0.5610386   0.58715271  0.64418677  0.70122083  0.7582549   0.81528896
#   0.87232304  0.89030782  0.84142104  0.7850253   0.72799123  0.67095717
#   0.6139241   0.55689004  0.49985596  0.4428219   0.37459879  0.29150757
#   0.17743943  0.37981422  0.26514073  0.26514073  0.26514073 -0.07713459
#  -0.32175425 -0.12751876 -0.18455182 -0.2415859  -0.29861996 -0.37187469
#  -0.46041011 -0.57447824 -0.67914142 -0.76653205 -0.82356611 -0.88060019
#  -0.96207714 -1.07614524 -1.19021341 -1.30428058 -1.41834865 -1.53241682
#  -1.60473249 -1.64415645 -1.64415645 -1.64415645 -1.64415645 -1.64415645
#  -1.63721088 -1.60923777 -1.55220469 -1.49517061 -1.43813652 -1.38110244
#  -1.32406835 -1.29219048 -1.27867393 -1.27867393 -1.27867393 -1.27867393
#  -1.27867393 -1.26515737 -1.2332794  -1.17624532 -1.11921123 -1.06217715
#  -1.00514316 -0.94810906 -0.86201404 -0.75489249 -0.64082436 -0.55243778
#  -0.48019796 -0.4231639  -0.36612983 -0.30909577 -0.2520617  -0.19502764
#  -0.13799357 -0.37413229 -0.08896195 -0.45560824 -0.26835729 -0.43945949
#  -0.58020412 -0.70367821 -0.81774633 -0.90628175 -0.97953648 -1.0365706
#  -1.03925472 -0.98652003 -0.87245189 -0.76649409 -0.68738261 -0.63034855
#  -0.57331448 -0.48162445 -0.37078585 -0.25671773 -0.1736265  -0.49634771
#  -0.21117738 -0.17306709 -0.29265433 -0.12169798 -0.17873204 -0.23576611
#  -0.29248151 -0.34544093 -0.36496607 -0.36496607 -0.36496607 -0.43705606
#  -0.53955955 -0.65362768 -0.73677584 -0.80610677 -0.86314084 -0.87376648
#  -0.84917276 -0.79146341 -0.72220741 -0.62569252 -0.51162439 -0.39755625
#  -0.20201117  0.16128968  0.25426035  0.44563789  0.62439991  0.79550111
#   0.84585232  0.83973185  0.78138319  0.68361065  0.54292196  0.37407335
#   0.21926674  0.13204493  0.40572054  0.12055121 -0.12350005 -0.2893079
#  -0.46041011 -0.48432756 -0.46273862 -0.40544184 -0.31989023 -0.21830677
#  -0.45298005  0.44326843  0.37065601  0.71195936  1.05008915  1.3472177
#   1.63238803  1.91755835  2.1596986   2.39245298  2.62058922  2.81256712
#   2.99305625  3.15739972  3.25517227  3.28986523  3.27775612  3.21664838
#   2.98723647  2.70206614  2.41689682  2.08283972  1.74063632  1.39843191
#   1.0562286   0.71402416  0.37407335  0.3529669  -0.22994633 -0.50441609
#  -0.72847771 -0.87245189 -0.98193891 -1.07971143 -1.09593211 -1.09593211
#  -1.09593211 -1.04614436 -0.99117605 -0.93601898 -0.91972338 -0.91319037
#  -0.91319037 -0.91319037 -0.91319037 -0.91319037 -0.91319037 -0.91319037
#  -0.9161572  -0.92430449 -1.029587   -1.14365417 -1.25659644 -1.32177784
#  -1.38226625 -1.44403124 -1.53773013 -1.64532117 -1.7536444  -1.84326873
#  -1.90721137 -1.93923912 -1.9229446  -1.66627276 -1.38110244 -1.09593211
#   0.30145793  0.30145793  0.30145793  0.30145793  0.30145793  0.30145793
#   0.30145793  0.30145793  0.30145793  0.30145793  0.30145793  0.30145793
#   0.30145793  0.30145793  0.30145793  0.30145793  0.30145793  0.30145793
#   0.30145793  0.30145793  0.30145793  0.30145793  0.30145793  0.30145793
#   0.30145793  0.30145793  0.30145793  0.30145793  0.30145793  0.30145793
#   0.30145793  0.30145793  0.3062648   0.33523884  0.36768517  0.39557938
#   0.40765248  0.40976621  0.42618868  0.46965024  0.56705418  0.66495857
#   0.75814502  0.82575179  0.89335756  0.95130565  0.95130565  0.95130565
#   0.94469671  0.91813709  0.88576866  0.85882046  0.84433294  0.84299737
#   0.84299737  0.84299737  0.84299737  0.84573544  0.85403557  0.88783846
#   0.92164234  0.9483568   0.95077222  0.95130565  0.95130565  0.95130565
#   0.95130565  0.95130565  0.95130565  0.95130565  0.95655804  0.96855223
#   1.00235509  1.03458965  1.05961389  1.05961389  1.05961389  1.05066746
#   1.02169342  0.98855786  0.96376733  0.95169524  0.95130565  0.94376171
#   0.92785071  0.89404783  0.86024394  0.82644106  0.79263817  0.75883529
#   0.74434776  0.77815065  0.81195453  0.83535353  0.8425968   0.84299737
#   0.84299737  0.84299737  0.84299737  0.83571015  0.82023269  0.7864298
#   0.75262592  0.71882303  0.68502014  0.65121726  0.61741337  0.58361049
#   0.5498076   0.50454397  0.44632816  0.37872239  0.32093013  0.27248389
#   0.238681    0.1982462   0.14899882  0.43763244  0.10917037 -0.16254534
#  -0.33156077 -0.5005772  -0.14005237 -0.17385525 -0.20765814 -0.24146102
#  -0.27526491 -0.30906779 -0.33325695 -0.34838978 -0.34838978 -0.35396383
#  -0.36977494 -0.40357782 -0.43738171 -0.48567112 -0.55327789 -0.62088366
#  -0.6742926  -0.71470542 -0.74850831 -0.78231119 -0.81611408 -0.84991697
#  -0.87470748 -0.88992922 -0.88992922 -0.88992922 -0.88992922 -0.88992922
#  -0.88992922 -0.88992922 -0.88992922 -0.88992922 -0.88992922 -0.88992922
#  -0.88992922 -0.90215716 -0.92373211 -0.95753599 -0.99133888 -1.02514175
#  -1.05894464 -1.08823034 -1.08653914 -1.05273625 -1.01893336 -1.00235409
#  -0.99823751 -0.99823751 -0.99823751 -0.99823751 -0.99823751 -1.00991999
#  -1.03135013 -1.06515402 -1.09234791 -1.10654483 -1.10654483 -1.10654483
#  -1.04859666 -0.94718804 -0.84577839 -0.81633684 -0.82784155 -0.86164544
#  -0.92571298 -1.00789522 -1.10930489 -1.21071346 -1.31212313 -1.4135328
#  -1.51494247 -1.61635114 -1.71776081 -1.81917048 -1.85895894 -1.86470078
#  -1.86470078 -1.86470078 -1.86470078 -1.86470078 -1.85005843 -1.82606903
#  -1.79226514 -1.75846225 -1.72465946 -1.69085657 -1.65705268 -1.62324979
#  -1.5894469  -1.55564401 -1.47911371 -1.38455876 -1.28314909 -1.21839132
#  -1.17001202 -1.13620913 -1.11615852 -1.10654483 -1.10654483 -1.10654483
#  -1.10654483 -1.10654483 -1.10654483 -1.10654483 -1.10654483 -1.10654483
#  -1.0847591  -1.05549531 -1.02169242 -0.98788956 -0.95408667 -0.92028279
#  -0.8864799  -0.85267702 -0.81954141 -0.79056737 -0.78162094 -0.78162094
#  -0.78162094 -0.75659766 -0.7243631  -0.69056022 -0.65675633 -0.62295345
#  -0.58915056 -0.55534767 -0.52154479 -0.48662809 -0.44316752 -0.3835722
#  -0.31489757 -0.24246295 -0.12142527  0.09960159  0.14899882  0.33521687
#   0.53256102  0.73537934  0.95962875  1.19068686  1.42730909  1.66393032
#   1.90055245  2.12999738  2.33040124  2.43105471  2.49866049  2.56626727
#   2.54695095  2.51314806  2.47934517  2.36880027  2.24410247  2.11022552
#   1.99432928  1.88744551  1.78603584  1.68462617  1.5832175   1.48180783
#   1.38039826  1.27898859  1.17757992  1.07617025  0.94525312  0.81126426
#   0.67493892  0.51558217  0.35043861  0.18656269  0.28741993 -0.2694741
#  -0.15645285 -0.23854614 -0.28147328 -0.3143971  -0.34578556 -0.34838978
#  -0.34838978 -0.3477215  -0.31874745 -0.28699238 -0.25038449 -0.19485082
#  -0.13108394 -0.28672067  0.05131118  0.38934204  0.14922157  0.2458024
#   0.43736074  0.64017905  0.84299737]

# %%
pyplot.title("Sample from the data")
pyplot.plot(X_train[2, 0], color='black')

# %% [markdown]
# ### Learning Shapelets

# %% [markdown]
# Train a model using *Learning Shapelets* with cross-entropy loss as proposed in the orginial paper.

# %%
def sample_ts_segments(X, shapelets_size, n_segments=10000):
    """
    Sample time series segments for k-Means.
    """
    n_ts, n_channels, len_ts = X.shape
    samples_i = random.choices(range(n_ts), k=n_segments)
    segments = numpy.empty((n_segments, n_channels, shapelets_size))
    for i, k in enumerate(samples_i):
        s = random.randint(0, len_ts - shapelets_size)
        segments[i] = X[k, :, s:s+shapelets_size]
    return segments

# %%
def get_weights_via_kmeans(X, shapelets_size, num_shapelets, n_segments=10000):
    """
    Get weights via k-Means for a block of shapelets.
    """
    segments = sample_ts_segments(X, shapelets_size, n_segments).transpose(0, 2, 1)
    k_means = TimeSeriesKMeans(n_clusters=num_shapelets, metric="euclidean", max_iter=50).fit(segments)
    clusters = k_means.cluster_centers_.transpose(0, 2, 1)
    return clusters

# %% [markdown]
# Initialize parameters:

# %%
n_ts, n_channels, len_ts = X_train.shape
loss_func = nn.CrossEntropyLoss()
num_classes = len(set(y_train))
# learn 48 shapelets
shapelets_size_and_len = {189: 16, 378: 16, 567: 16}
dist_measure = "euclidean"
lr = 4e-3
wd = 1e-4
epsilon = 1e-7
batch_size = 256
shuffle = True
drop_last = False

# %% [markdown]
# Initialize shapelets via k-Means:

# %%
shapelets_blocks = []
for i, (shapelets_size, num_shapelets) in enumerate(shapelets_size_and_len.items()):
    weights_block = get_weights_via_kmeans(X_train, shapelets_size, num_shapelets)
    shapelets_blocks.append(weights_block)

# %% [markdown]
# Initialize *Learning Shapelets* model:

# %%
learning_shapelets = LearningShapelets(shapelets_size_and_len=shapelets_size_and_len,
                                       in_channels=n_channels,
                                       num_classes=num_classes,
                                       loss_func=loss_func,
                                       to_cuda=False,
                                       verbose=1,
                                       dist_measure=dist_measure)

# %% [markdown]
# Set weights:

# %%
for i, shapelets_block in enumerate(shapelets_blocks):
    learning_shapelets.set_shapelet_weights_of_block(i, shapelets_block)

# %% [markdown]
# Initialize optimizer for the *Learning Shapelets* model:

# %%
optimizer = optim.Adam(learning_shapelets.model.parameters(), lr=lr, weight_decay=wd, eps=epsilon)
learning_shapelets.set_optimizer(optimizer)

# %% [markdown]
# #### Train Learning Shapelets Model

# %%
def eval_accuracy(model, X, Y):
    predictions = model.predict(X)
    if len(predictions.shape) == 2:
        predictions = predictions.argmax(axis=1)
    print(f"Accuracy: {(predictions == Y).sum() / Y.size}")
    return (predictions == Y).sum() / Y.size

# %%
epochs = 200
n_epoch_steps = 5 * 8

# %%
losses = []
train_acc_last = 0
for _ in range(n_epoch_steps):
    losses += learning_shapelets.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, shuffle=shuffle, drop_last=drop_last)
    train_acc_current = eval_accuracy(learning_shapelets, X_train, y_train)
    if train_acc_current - train_acc_last < 1e-3 or train_acc_current == 1.0:
        break
    train_acc_last = train_acc_current
# Out:
# Loss: 0.1311575025320053: 100%|██████████| 200/200 [18:13<00:00,  5.47s/it]
# Accuracy: 0.9877232142857143
# Loss: 0.04281908646225929: 100%|██████████| 200/200 [16:17<00:00,  4.89s/it]
# Accuracy: 0.9966517857142857
# Loss: 0.04290619120001793: 100%|██████████| 200/200 [16:37<00:00,  4.99s/it]
# Accuracy: 1.0

# %%
pyplot.plot(losses, color='black')
pyplot.title("Loss over Training Steps")
pyplot.xlabel("training step i")
pyplot.ylabel("loss")
pyplot.show()

# %% [markdown]
# #### Evaluate Accuracy of Learning Shapelets Model

# %% [markdown]
# Load test data:

# %%
# Load data set
X_test = numpy.load(open(os.path.join('data', f'{dataset}_test.npy'), 'rb'))
print(f"Shape X_train: {X_test.shape}")
y_test = numpy.load(open(os.path.join('data', f'{dataset}_test_labels.npy'), 'rb'))
# normalize data
X_train, scaler = normalize_data(X_train, scaler)
# Out:
# Shape X_train: (3582, 1, 945)

# %%
test_acc = eval_accuracy(learning_shapelets, X_test, y_test)
# Out:
# Accuracy: 0.9240647682858738

# %% [markdown]
# ### Learning Shapelets with $\mathcal{L_R}$ loss

# %% [markdown]
# Train a model using *Learning Shapelets* with $\mathcal{L_R}$ loss as proposed here.

# %% [markdown]
# Initialize additional parameters:

# %%
l1 = 0.1
l2 = 0.01
k = int(0.1 * batch_size) if batch_size <= X_train_size else X_train_size

# %% [markdown]
# Initialize model:

# %%
learning_shapelets_Lr = LearningShapelets(shapelets_size_and_len=shapelets_size_and_len,
                                       in_channels=n_channels,
                                       num_classes=num_classes,
                                       loss_func=loss_func,
                                       to_cuda=False,
                                       verbose=1,
                                       dist_measure=dist_measure,
                                       l1=l1,
                                       l2=l2,
                                       k=k)

# %% [markdown]
# Set weights:

# %%
for i, shapelets_block in enumerate(shapelets_blocks):
    learning_shapelets_Lr.set_shapelet_weights_of_block(i, shapelets_block)

# %% [markdown]
# Initialize optimizer for the *Learning Shapelets* model:

# %%
optimizer = optim.Adam(learning_shapelets_Lr.model.parameters(), lr=lr, eps=epsilon)
learning_shapelets_Lr.set_optimizer(optimizer)

# %% [markdown]
# #### Train Model with $\mathcal{L_R}$

# %%
losses_acc = []
losses_dist = []
losses_sim = []
train_acc_last_Lr = 0
for _ in range(n_epoch_steps):
    losses_acc_i, losses_dist_i, losses_sim_i = \
        learning_shapelets_Lr.fit(X_train, y_train, epochs=epochs, batch_size=batch_size,
                                  shuffle=shuffle, drop_last=drop_last)
    losses_acc += losses_acc_i
    losses_dist += losses_dist_i
    losses_sim += losses_sim_i
    train_acc_current_Lr = eval_accuracy(learning_shapelets_Lr, X_train, y_train)
    if train_acc_current_Lr - train_acc_last_Lr < 1e-3 or train_acc_current_Lr == 1.0:
        break
    train_acc_last_Lr = train_acc_current_Lr
# Out:
# Loss CE: 0.07395356893539429, Loss dist: 0.883414089679718, Loss sim: 0.0002364551619393751: 100%|██████████| 200/200 [32:05<00:00,  9.63s/it]
# Accuracy: 0.9888392857142857
# Loss CE: 0.02141149342060089, Loss dist: 0.8354572653770447, Loss sim: 0.00029462494421750307: 100%|██████████| 200/200 [32:16<00:00,  9.68s/it]
# Accuracy: 1.0

# %%
fig, axes = pyplot.subplots(1, 3)
fig.set_size_inches(16, 4)

axes[0].plot(losses_acc, color='black')
axes[0].title.set_text("Cross-Entropy Loss over Training Steps")

axes[1].plot(losses_dist, color='black')
axes[1].title.set_text("Distance Loss over Training steps")

axes[2].plot(losses_sim, color='black')
axes[2].title.set_text("Similarity Loss over Training steps")

pyplot.show()

# %% [markdown]
# ### Evaluate Accuracy of Learning Shapelets Model with $\mathcal{L_R}$

# %%
test_acc_Lr = eval_accuracy(learning_shapelets_Lr, X_test, y_test)
# Out:
# Accuracy: 0.9268565047459519

# %% [markdown]
# ## Compare the Shapelets of the two Models

# %% [markdown]
# Define some helper functions:

# %%
def filterNanFromShapelet(shapelet):
    """
    Filter NaN values from a shapelet.
    Needed for the output of learning shapelets from tslearn, since smaller size shapelets are padded with NaN values.
    Note: Make sure the NaN values are only leading or trailing.
    """
    return shapelet[~numpy.isnan(shapelet)]

def lead_pad_shapelet(shapelet, pos):
    """
    Adding leading NaN values to shapelet to plot it on a time series at the best matching position.
    """
    pad = numpy.empty(pos)
    pad[:] = numpy.NaN
    padded_shapelet = numpy.concatenate([pad, filterNanFromShapelet(shapelet)])
    return padded_shapelet

def torch_dist_ts_shapelet(ts, shapelet, to_cuda=False):
    """
    Use PyTorch to calculate the distance between a shapelet and a time series.
    Implemented via unfolding.
    """
    if not isinstance(ts, torch.Tensor):
        ts = torch.tensor(ts, dtype=torch.float)
    if not isinstance(shapelet, torch.Tensor):
        shapelet = torch.tensor(shapelet, dtype=torch.float)
    if to_cuda:
        ts = ts.cuda()
        shapelet = shapelet.cuda()
    if shapelet.dim() == 1:
        shapelet = torch.unsqueeze(shapelet, 0)
    # unfold time series to emulate sliding window
    ts = ts.unfold(1, shapelet.shape[1], 1)
    # calculate euclidean distance over each segment
    dists = torch.sum(torch.cdist(ts, shapelet, p=2), dim=0)
    # filter min dist
    d_min, d_argmin = torch.min(dists, 0)
    return (d_min.item(), d_argmin.item())

def dists_to_shapelet(data, shapelet, to_cuda=False):
    """
    Calculate the distances of a shapelet to a bunch of time series.
    """
    shapelet = filterNanFromShapelet(shapelet)
    dists = []
    for i in range(len(data)):
        dists.append((torch_dist_ts_shapelet(data[i,:], shapelet, to_cuda=to_cuda), i))
    return sorted(dists, key=lambda x: x[0][0])

def plot_shapelet_on_ts_at_i(shapelet, ts, i, title="", axis=None):
    """
    Plot a shapelet on top of a timeseries
    """
    shapelet = filterNanFromShapelet(shapelet)
    padded_shapelet = lead_pad_shapelet(shapelet, i)
    if axis is None:
        pyplot.clf()
        pyplot.rcParams["figure.figsize"] = (23, 6)
        pyplot.plot(ts)
        pyplot.plot(padded_shapelet)
    else:
        axis.plot(ts)
        axis.plot(padded_shapelet)

# %%
shapelets_ce = learning_shapelets.get_shapelets()
shapelets_Lr = learning_shapelets_Lr.get_shapelets()
n_shapelets_ce = shapelets_ce.shape[0]
n_shapelets_Lr = shapelets_Lr.shape[0]
n_shapelets = max(n_shapelets_ce, n_shapelets_Lr)

# %%
fig, axes = pyplot.subplots(n_shapelets, 2)
pyplot.rcParams['axes.facecolor'] = 'white'
pyplot.rcParams['savefig.facecolor']='white'
fig.suptitle(f'Learned Shapelets\nDataset: {dataset}\nLeft: Learning Shapelets (Acc: {test_acc}%, {n_shapelets_ce} Shapelets)\nRight: This work (Acc: {test_acc_Lr}%, {n_shapelets_Lr} Shapelets)')
fig.set_size_inches(14, 2 * n_shapelets)

relative_distances_gra = []
relative_distances_contrastive = []
for i in range(n_shapelets):
    if i < n_shapelets_ce:
        shapelet_ce = filterNanFromShapelet(shapelets_ce[i, 0])
        best_match_ce = dists_to_shapelet(X_test, shapelet_ce, to_cuda=False)[0]
        plot_shapelet_on_ts_at_i(shapelet_ce, X_test[best_match_ce[1], 0], best_match_ce[0][1], axis=axes[i, 0])
    if i < n_shapelets_Lr:
        shapelet_Lr = filterNanFromShapelet(shapelets_Lr[i, 0])
        best_match_Lr = dists_to_shapelet(X_test, shapelet_Lr, to_cuda=False)[0]
        plot_shapelet_on_ts_at_i(shapelet_Lr, X_test[best_match_Lr[1], 0], best_match_Lr[0][1], axis=axes[i, 1])
pyplot.tight_layout(rect=[0, 0.03, 1, 0.98])
pyplot.show()
